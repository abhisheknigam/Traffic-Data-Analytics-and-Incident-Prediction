# %%
import pylab
import pandas as pd
df = pd.read_csv("events_train.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)

# %%
df_prediction_trial = pd.read_csv("prediction_trials.tsv", na_values=['-'], delimiter="\t", error_bad_lines=False)

# %%
df[(pd.isnull(df["closed_tstamp"] ) == True)].describe()
# Out:
# /Users/abhisheknigam/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         latitude  longitude  number_of_responders  lanes_affected
# count  29.000000       29.0                   0.0             0.0
# mean  -77.012102        0.0                   NaN             NaN
# std     0.021525        0.0                   NaN             NaN
# min   -77.072502        0.0                   NaN             NaN
# 25%   -77.019615        0.0                   NaN             NaN
# 50%   -77.010185        0.0                   NaN             NaN
# 75%   -76.998329        0.0                   NaN             NaN
# max   -76.973724        0.0                   NaN             NaN

# %%
df.describe()
# Out:
# /Users/abhisheknigam/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             latitude      longitude  number_of_responders  lanes_affected
# count  844038.000000  844038.000000         844020.000000   448683.000000
# mean       39.018729     -77.000140              0.925803        1.111032
# std         0.709728       0.533564              1.436312        1.285251
# min       -77.072502     -79.468413              0.000000        0.000000
# 25%              NaN            NaN                   NaN             NaN
# 50%              NaN            NaN                   NaN             NaN
# 75%              NaN            NaN                   NaN             NaN
# max        39.430760       0.000000             41.000000       28.000000

# %%
df
# Out:
#                                            event_id  \
# 0       MDOT_CHART_4aff02b300110095003f0be8b3035daa
# 1       MDOT_CHART_4fffe16700a60095003f04e897035daa
# 2       MDOT_CHART_89ff153200d70096003f05e89f035daa
# 3       MDOT_CHART_0aff378a01e50096003f05e897035daa
# 4       MDOT_CHART_9aff47fb01f40096003f05e897035daa
# 5       MDOT_CHART_8000323c00f80096003f16e83d035daa
# 6       MDOT_CHART_19004d6f01f90096003f05e897035daa
# 7       MDOT_CHART_d1ff165a00fb0097003f07e897035daa
# 8       MDOT_CHART_0dff9e0d01fd0097003f05e897035daa
# 9       MDOT_CHART_4900776800fd0097003f06e89f035daa
# 10      MDOT_CHART_2e003adb00fd0097003f17e83d035daa
# 11      MDOT_CHART_98ff05f000190098003f8ee833035daa
# 12      MDOT_CHART_caff091c001b0098003f8ee833035daa
# 13      MDOT_CHART_80ff0ad1001b0098003f8ee833035daa
# 14      MDOT_CHART_fffeb0c701220098003f05e897035daa
# 15      MDOT_CHART_f9feb2b801290098003f05e897035daa
# 16      MDOT_CHART_b4ffd240013c0098003f05e897035daa
# 17      MDOT_CHART_93ff4ed000ec0098003f8de833035daa
# 18      MDOT_CHART_89ff02c500370099003f8ee833035daa
# 19      MDOT_CHART_d0ff90e7003c0099003f16e83d035daa
# 20      MDOT_CHART_7bff399902410099003f05e897035daa
# 21      MDOT_CHART_e1ff44ce005c009d003f06e89f035daa
# 22      MDOT_CHART_27001a370064009d003f05e89f035daa
# 23      MDOT_CHART_24001c310065009d003f05e89f035daa
# 24      MDOT_CHART_56001e610065009d003f05e89f035daa
# 25      MDOT_CHART_5b00394f0067009d003f07e897035daa
# 26      MDOT_CHART_7a005a2f007e009d003f06e89f035daa
# 27      MDOT_CHART_81ff34400080009d003f8ce833035daa
# 28      MDOT_CHART_b2ff5d610081009d003f06e89f035daa
# 29      MDOT_CHART_15fe9f8a0082009d003f05e897035daa
# ...                                             ...
# 844019  MDOT_CHART_9700049b0f7507a40054fa2ec4235c0a
# 844020                        VDOT_NOVA_NOVA7024780
# 844021               VaTraffic_INNO7024780-12312014
# 844022  MDOT_CHART_44011f2b0f7707a40054fa2ec4235c0a
# 844023  MDOT_CHART_fd00d0310f7907a40054fa2ec4235c0a
# 844024  MDOT_CHART_2c014fe0107907a40054fa2ec4235c0a
# 844025                        VDOT_NOVA_NOVA7025129
# 844026  MDOT_CHART_d001745d107b07a40054fa2ec4235c0a
# 844027               VaTraffic_INNO7025129-12312014
# 844028  MDOT_CHART_7400abc8107d07a40054fa2ec4235c0a
# 844029                        VDOT_NOVA_NOVA7025259
# 844030               VaTraffic_INNO7025259-12312014
# 844031                        VDOT_NOVA_NOVA7025347
# 844032               VaTraffic_INNO2847148-12312014
# 844033  MDOT_CHART_66000559118307a40054fa2ec4235c0a
# 844034               VaTraffic_INNO7025347-12312014
# 844035  MDOT_CHART_b0ff1294118507a40054fa2ec4235c0a
# 844036                            DDOT_CAPTOP_75449
# 844037  MDOT_CHART_ac004955118907a40054fa2ec4235c0a
# 844038  MDOT_CHART_ebffcb0f118c07a40054fa2ec4235c0a
# 844039  MDOT_CHART_acffe0bb118c07a40054fa2ec4235c0a
# 844040  MDOT_CHART_f0ff99ca0a8701310055fa2ec4235c0a
# 844041  MDOT_CHART_2b008cff0c9801310055fa2ec4235c0a
# 844042  MDOT_CHART_c60043de0d9c01310055fa2ec4235c0a
# 844043  MDOT_CHART_2c00bdc00da601310055fa2ec4235c0a
# 844044  MDOT_CHART_b100d62a0da801310055fa2ec4235c0a
# 844045  MDOT_CHART_e100ff2f0daa01310055fa2ec4235c0a
# 844046  MDOT_CHART_bc0049bc0ead01310055fa2ec4235c0a
# 844047  MDOT_CHART_f600579f12f201310055fa2ec4235c0a
# 844048  MDOT_CHART_9200870712f601310055fa2ec4235c0a
#
#                                         event_description  \
# 0                              Action Event @ BWI Parking
# 1              Incident @ I-95 PRIOR MD 202[Vehicle Fire]
# 2       Incident @ N/B I-97 AT MD 100[Collision, Perso...
# 3       Incident @ I-270 N. OF SHADY GROVE RD[Debris I...
# 4       Incident @ MD 320 AT SLIGO AVE[Collision, Fata...
# 5        Congestion Event @ I-895 BALTIMORE HARBOR TUNNEL
# 6                Disabled Vehicle Event @ I-495 AT MD 187
# 7       Incident @ I-95 AT MD 414[Collision, Property ...
# 8           Incident @ I-495 PAST I-95[Debris In Roadway]
# 9       Incident @ MD 702 AT MIDDLEBOROU[Collision, Pe...
# 10      Incident @ I-95 MM 54.3 @ McCOMAS ST ON[Disabl...
# 11                                    Action Event @ test
# 12                                Congestion Event @ test
# 13                          Disabled Vehicle Event @ test
# 14               Congestion Event @ I-495 PRIOR TO MD 355
# 15      Incident @ MD 5  AT BEECH RD[Collision, Person...
# 16          Incident @ US 50 AT MD 197[Debris In Roadway]
# 17                        Action Event @ MD 648 @ WELLHAM
# 18                          Disabled Vehicle Event @ test
# 19                    Incident @ I-695 @ EXIT 2 MD10 L/LN
# 20                  Disabled Vehicle Event @ I-95 AT RT 4
# 21      Incident @ I-95 @ I-195  R/S[Collision, Proper...
# 22      Incident @ E/B I-70 EAST OF  I-6[Collision, Pr...
# 23                       Incident @ I/L I-695 X-38[Other]
# 24                   Incident @ N/B I-97 AT MD 648[Other]
# 25                      Incident @ I-495 AT MD 190[Other]
# 26      Incident @ I-83  ( JFX )RAMP TO [Collision, Pr...
# 27      Incident @ MD 85 AT I-270[Collision, Personal ...
# 28                    Congestion Event @ MD 100 E.of I-97
# 29                   Congestion Event @ I-495 PRIO MD 650
# ...                                                   ...
# 844019  Disabled Vehicle Event @ I-270 SOUTH PRIOR TO ...
# 844020                                                NaN
# 844021  Fairfax (County) - I-395S - 2.0 - South - the ...
# 844022  Incident @ I-895 SOUTH AT MP 9.4 (BALTIMORE HA...
# 844023  Incident @ JENNIFER RD WEST AT US 50 [Collisio...
# 844024  Incident @ MD 100 EAST PRIOR TO EXIT 1B EXECUT...
# 844025                                                NaN
# 844026  Disabled Vehicle Event @ MD 295 NORTH AT LANDO...
# 844027  Fairfax (County) - I-66E - 56.3 - East - the r...
# 844028  Disabled Vehicle Event @ I-895 SOUTH PRIOR TO ...
# 844029                                                NaN
# 844030  Fairfax (County) - I-395N - 1.1 - North - the ...
# 844031                                                NaN
# 844032  Fairfax (County) - North - Traffic - Vehicle A...
# 844033  Disabled Vehicle Event @ I-695 OUTER LOOP PRIO...
# 844034  Fairfax (County) - I-495N - 44.0 - North - the...
# 844035  Disabled Vehicle Event @ I-695 INNER LOOP PAST...
# 844036                                                NaN
# 844037  Disabled Vehicle Event @ I-395 SOUTH PRIOR TO ...
# 844038  Disabled Vehicle Event @ I-695 INNER LOOP AT E...
# 844039  Incident @ I-83 NORTH PRIOR TO BALTO BELTWAY [...
# 844040  Action Event @ MD 201 NORTH AT LYDELL RD [Othe...
# 844041  Incident @ MD 169 EAST FROM MAPLE RD TO ORCHAR...
# 844042  Planned Closure @ I-95 SOUTH AT EXIT 15 MD 214...
# 844043  Action Event @ I-95 NORTH AT MP 54.8 (FORT MCH...
# 844044  Planned Closure @ I-95 NORTH AT MP 54.8 (FORT ...
# 844045  Planned Closure @ I-95 SOUTH AT MP 54.8 (FORT ...
# 844046  Planned Closure @ I-95 SOUTH PAST EXIT 55 KEY ...
# 844047  Incident @ I-495 OUTER LOOP AT EXIT 34 MD 355 ...
# 844048  Incident @ I-97 SOUTH PRIOR TO BRIGHTVIEW DR [...
#
#                      start_tstamp           confirmed_tstamp  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN  2003-10-22T16:17:01-04:00
# 4                             NaN  2003-10-22T17:23:45-04:00
# 5                             NaN  2003-10-22T17:36:41-04:00
# 6                             NaN  2003-10-22T17:41:20-04:00
# 7                             NaN                        NaN
# 8                             NaN                        NaN
# 9                             NaN  2003-10-23T12:11:18-04:00
# 10                            NaN                        NaN
# 11                            NaN                        NaN
# 12                            NaN                        NaN
# 13                            NaN                        NaN
# 14                            Na
# 844026  accidentsAndIncidents             disabled vehicle
# 844027  accidentsAndIncidents             disabled vehicle
# 844028  accidentsAndIncidents             disabled vehicle
# 844029  accidentsAndIncidents             disabled vehicle
# 844030  accidentsAndIncidents             disabled vehicle
# 844031  accidentsAndIncidents                     accident
# 844032  accidentsAndIncidents                     accident
# 844033  accidentsAndIncidents             disabled vehicle
# 844034  accidentsAndIncidents                     accident
# 844035  accidentsAndIncidents             disabled vehicle
# 844036  accidentsAndIncidents             disabled vehicle
# 844037  accidentsAndIncidents             disabled vehicle
# 844038  accidentsAndIncidents             disabled vehicle
# 844039  accidentsAndIncidents             disabled vehicle
# 844040  accidentsAndIncidents                     incident
# 844041               roadwork        emergency maintenance
# 844042               roadwork  road maintenance operations
# 844043  accidentsAndIncidents                     incident
# 844044               roadwork  road maintenance operations
# 844045               roadwork  road maintenance operations
# 844046               roadwork  road maintenance operations
# 844047  accidentsAndIncidents                     accident
# 844048  accidentsAndIncidents              injury accident
#
#                                                  location   latitude  \
# 0                                             BWI Parking  39.181837
# 1                                       I-95 PRIOR MD 202  38.916545
# 2                                      N/B I-97 AT MD 100  39.152326
# 3                              I-270 N. OF SHADY GROVE RD  39.113290
# 4                                     MD 320 AT SLIGO AVE  38.991634
# 5                           I-895 BALTIMORE HARBOR TUNNEL  39.228030
# 6                                         I-495 AT MD 187  39.015029
# 7                                          I-95 AT MD 414  38.808339
# 8                                         I-495 PAST I-95  39.021560
# 9                              MD 702 AT MIDDLEBOROUGH RD  39.302230
# 10                      I-95 MM 54.3 @ McCOMAS ST ON-RAMP  39.262379
# 11                                                   test  39.295088
# 12                                                   test  39.257424
# 13                                                   test  39.100492
# 14                                  I-495 PRIOR TO MD 355  39.015328
# 15                                      MD 5  AT BEECH RD  38.827866
# 16                                        US 50 AT MD 197  38.952300
# 17                                       MD 648 @ WELLHAM  39.104998
# 18                                                   test  39.191102
# 19                               I-695 @ EXIT 2 MD10 L/LN  38.976606
# 20                                           I-95 AT RT 4  38.967045
# 21                                      I-95 @ I-195  R/S  39.234580
# 22                                E/B I-70 EAST OF  I-695  39.305274
# 23                                         I/L I-695 X-38  39.424658
# 24                                     N/B I-97 AT MD 648  38.981639
# 25                                        I-495 AT MD 190  38.989177
# 26                        I-83  ( JFX )RAMP TO I-695  O/L  39.427467
# 27                                         MD 85 AT I-270  39.381711
# 28                                       MD 100 E.of I-97  39.152632
# 29                                      I-495 PRIO MD 650  39.017653
# ...                                                   ...        ...
# 844019  I-270 SOUTH PRIOR TO EXIT 22 MD 109 OLD HUNDRE...  39.277836
# 844020                                                NaN  38.810620
# 844021                                                NaN  38.810620
# 844022    I-895 SOUTH AT MP 9.4 (BALTIMORE HARBOR TUNNEL)  39.252798
# 844023                          JENNIFER RD WEST AT US 50  38.991407
# 844024  MD 100 EAST PRIOR TO EXIT 1B EXECUTIVE PARK DRIVE  39.235488
# 844025                                                NaN  38.856968
# 844026                        MD 295 NORTH AT LANDOVER RD  38.935145
# 844027                                                NaN  38.856968
# 844028  I-895 SOUTH PRIOR TO EXIT 8B FRANKFURST AVE(MM...  39.241164
# 844029                                                NaN  38.801632
# 844030                                                NaN  38.801632
# 844031                                                NaN  38.948760
# 844032                                                NaN  38.909180
# 844033  I-695 OUTER LOOP PRIOR TO EXIT 23A I 83 JONES ...  39.411472
# 844034                                                NaN  38.948760
# 844035  I-695 INNER LOOP PAST EXIT 3 MD 2 GOVERNOR RIT...  39.207292
# 844036                                                NaN  38.887138
# 844037          I-395 SOUTH PRIOR TO EXIT 53(MM 04 RT SH)  39.267708
# 844038  I-695 INNER LOOP AT EXIT 3 MD 2 GOVERNOR RITCH...  39.207292
# 844039                  I-83 NORTH PRIOR TO BALTO BELTWAY  39.420183
# 844040                          MD 201 NORTH AT LYDELL RD  38.926120
# 844041            MD 169 EAST FROM MAPLE RD TO ORCHARD RD  39.205572
# 844042           I-95 SOUTH AT EXIT 15 MD 214 CENTRAL AVE  38.892004
# 844043  I-95 NORTH AT MP 54.8 (FORT MCHENRY TUNNEL)  B...  39.261274
# 844044  I-95 NORTH AT MP 54.8 (FORT MCHENRY TUNNEL) BO...  39.261274
# 844045  I-95 SOUTH AT MP 54.8 (FORT MCHENRY TUNNEL) BO...  39.261274
# 844046  I-95 SOUTH PAST EXIT 55 KEY HIGHWAY(MM 54.5-50.5)  39.266912
# 844047  I-495 OUTER LOOP AT EXIT 34 MD 355 ROCKVILLE PIKE  39.016556
# 844048                  I-97 SOUTH PRIOR TO BRIGHTVIEW DR  39.110902
#
#         longitude  number_of_responders  lanes_affected
# 0      -76.672123                   0.0             NaN
# 1      -76.851412                   6.0             1.0
# 2      -76.644871                   4.0             1.0
# 3      -77.190120                   2.0             NaN
# 4      -77.010207                   8.0             6.0
# 5      -76.624734                   0.0             NaN
# 6      -77.118409                   1.0             NaN
# 7      -76.970618                   4.0             1.0
# 8      -76.951944                   3.0             1.0
# 9      -76.443545                   5.0             4.0
# 10     -76.586255                   1.0             NaN
# 11     -77.051889                   3.0             NaN
# 12     -77.009216                   0.0             NaN
# 13     -76.690303                   1.0             NaN
# 14     -77.100015                   0.0             NaN
# 15     -76.928021                  19.0             7.0
# 16     -76.742986                   1.0             0.0
# 17     -76.551996                   1.0             NaN
# 18     -76.945298                   1.0             NaN
# 19     -76.621771                   2.0             2.0
# 20     -76.865417                   1.0             NaN
# 21     -76.708900                   2.0             2.0
# 22     -76.741292                   3.0             NaN
# 23     -76.444528                   1.0             NaN
# 24     -76.573940                   2.0             NaN
# 25     -77.156684                   3.0             2.0
# 26     -76.635294                   3.0             NaN
# 27     -77.408763                   3.0             5.0
# 28     -76.645120                   0.0             NaN
# 29     -76.925672                   0.0             NaN
# ...           ...                   ...             ...
# 844019 -77.323328                   1.0             NaN
# 844020 -77.151020                   1.0             1.0
# 844021 -77.151016                   1.0             1.0
# 844022 -76.572365                   2.0             0.0
# 844023 -76.547172                   5.0             0.0
# 844024 -76.813984                   4.0             1.0
# 844025 -77.374000                   1.0             1.0
# 844026 -76.916987                   1.0             NaN
# 844027 -77.374000                   1.0             1.0
# 844028 -76.593360                   2.0             NaN
# 844029 -77.164040                   1.0             1.0
# 844030 -77.164040                   1.0             1.0
# 844031 -77.199800                   1.0             1.0
# 844032 -77.297675                   1.0             1.0
# 844033 -76.663696                   1.0             NaN
# 844034 -77.199800                   1.0             1.0
# 844035 -76.606632                   1.0             NaN
# 844036 -77.020073                   0.0             NaN
# 844037 -76.626048                   2.0             NaN
# 844038 -76.606632                   1.0             NaN
# 844039 -76.641375                   1.0             NaN
# 844040 -76.928052                   0.0             NaN
# 844041 -76.658424                   0.0             2.0
# 844042 -76.846872                   0.0             3.0
# 844043 -76.575552                   0.0             NaN
# 844044 -76.575552                   0.0             2.0
# 844045 -76.575552                   0.0             2.0
# 844046 -76.600752                   0.0             3.0
# 844047 -77.100400                   2.0             0.0
# 844048 -76.632733                   3.0             3.0
#
# [844049 rows x 13 columns]

# %%
def set_Start_Timestamp(row):
    if pd.isnull(row["start_tstamp"]) == False:
        return row["start_tstamp"]
    elif pd.isnull(row["confirmed_tstamp"]) == False:
        return row["confirmed_tstamp"]
    elif pd.isnull(row["created_tstamp"]) == False:
        return row["created_tstamp"]
    else: 
        return None

df["for_prediction_timestamp"] = df.apply(lambda row: set_Start_Timestamp(row), axis = 1)
df["count"] = df["for_prediction_timestamp"]

# %%
df = df[~ pd.isnull(df["for_prediction_timestamp"]) == True]

# %%
df.describe()
# Out:
# /Users/abhisheknigam/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             latitude      longitude  number_of_responders  lanes_affected
# count  843915.000000  843915.000000         843897.000000   448620.000000
# mean       39.018699     -77.000125              0.925654        1.111041
# std         0.709772       0.533588              1.436208        1.285217
# min       -77.072502     -79.468413              0.000000        0.000000
# 25%              NaN            NaN                   NaN             NaN
# 50%              NaN            NaN                   NaN             NaN
# 75%              NaN            NaN                   NaN             NaN
# max        39.430760       0.000000             41.000000       28.000000

# %%
event_types = {"accidentsAndIncidents" : "1",
"roadwork" : "2",
"precipitation" : "3",
"deviceStatus" : "4",
"obstruction" : "5",
"trafficConditions" : "6"
}

# %%
def assign_Feature_Event_Type(row):
    if row["event_type"] in event_types:
        return event_types[row["event_type"]]
    else:
        return None
df["feature_event_type"] = df.apply(lambda row: assign_Feature_Event_Type(row) , axis= 1)
# Out:
# /Users/abhisheknigam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df["feature_event_type"].describe()
# Out:
# count     837813
# unique         6
# top            1
# freq      549977
# Name: feature_event_type, dtype: object

# %%
df = df[~ pd.isnull(df["feature_event_type"]) == True]

# %%
df.describe()
# Out:
# /Users/abhisheknigam/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             latitude      longitude  number_of_responders  lanes_affected
# count  837802.000000  837802.000000         837813.000000   445750.000000
# mean       39.022436     -77.003052              0.924016        1.107165
# std         0.202775       0.283978              1.430806        1.276831
# min        36.536983     -79.468413              0.000000        0.000000
# 25%              NaN            NaN              0.000000             NaN
# 50%              NaN            NaN              1.000000             NaN
# 75%              NaN            NaN              1.000000             NaN
# max        39.430760     -76.388454             41.000000       28.000000

# %%
df = df.sort_values(["latitude","longitude"])

# %%
df_prediction_trial = df_prediction_trial.sort_values(["se_lat","nw_lon","nw_lat","se_lon"])

# %%
df_prediction_trial["start"] = pd.to_datetime(df_prediction_trial["start"])
df_prediction_trial["end"] = pd.to_datetime(df_prediction_trial["end"])

# %%
df["for_prediction_timestamp"] = pd.to_datetime(df["for_prediction_timestamp"])
df["closed_tstamp"] = pd.to_datetime(df["closed_tstamp"])

# %%
df_acci_inci = df[df["event_type"] == "accidentsAndIncidents"]
df_road_work = df[df["event_type"] == "roadwork"]
df_precipitation = df[df["event_type"] == "precipitation"]
df_deviceStatus = df[df["event_type"] == "deviceStatus"]
df_obstruction = df[df["event_type"] == "obstruction"]
df_trafficConditions = df[df["event_type"] == "trafficConditions"]


event_types_df = {"accidentsAndIncidents" : df_acci_inci,
"roadwork" : df_road_work,
"precipitation" : df_precipitation,
"deviceStatus" : df_deviceStatus,
"obstruction" : df_obstruction,
"trafficConditions" : df_trafficConditions
}

# %%
df['month'] = df['for_prediction_timestamp'].dt.month
df['year'] = df['for_prediction_timestamp'].dt.year

# %%
df_grouped = df.groupby(["year","month"])["count"].count()

# %%
df_new = df_grouped

# %%
df_new.describe()
# Out:
# count      137.000000
# mean      6115.423358
# std       5809.587324
# min          8.000000
# 25%        586.000000
# 50%       6209.000000
# 75%      11209.000000
# max      17375.000000
# Name: count, dtype: float64

# %%
import time
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
import numpy as np
reg_iter = 1
total_error = []

def linear_regression(x_train, y_train, x_test, y_test, x_predict):
    if len(x_train) < 2 or len(x_test) == 0 or (len(x_train) != len(y_train)) or (len(x_test) != len(y_test)) :
        return np.zeros(2)

    global reg_iter
    reg_iter = reg_iter + 1
#     if reg_iter == 4:
#         print(x_test)
#         print(y_test)
    #print('\ntraining regression for cols : ' + str(reg_iter))

    regression_model = LinearRegression()
    regression_model.fit(x_train, y_train)
    #     print('Coefficients: \n', regression_model.coef_)
    predicted_ = regression_model.predict(x_test)
#     for val in zip(predicted_, y_test):
#         print(str(val[0]) + '\t' + str(val[1]))
    error = np.mean((predicted_ - y_test) ** 2)
    total_error.append(error)
    return regression_model.predict(x_predict)

# %%
df.columns
# Out:
# Index(['event_id', 'event_description', 'start_tstamp', 'confirmed_tstamp',
#        'created_tstamp', 'closed_tstamp', 'event_type', 'event_subtype',
#        'location', 'latitude', 'longitude', 'number_of_responders',
#        'lanes_affected', 'for_prediction_timestamp', 'count',
#        'feature_event_type', 'month', 'year'],
#       dtype='object')

# %%
df_event = df
del df_event["event_id"]
del df_event["event_description"]
del df_event["start_tstamp"]
del df_event["confirmed_tstamp"]
del df_event["created_tstamp"]
del df_event["event_subtype"]
del df_event["location"]
del df_event["number_of_responders"]
del df_event["lanes_affected"]
del df_event["feature_event_type"]

# %%
df_prediction_trial['month1'] = df_prediction_trial['start'].dt.month
df_prediction_trial['month2'] = df_prediction_trial['end'].dt.month

df_prediction_trial['year1'] = df_prediction_trial['start'].dt.year
df_prediction_trial['year2'] = df_prediction_trial['end'].dt.year

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/abhisheknigam/anaconda/lib/python3.5/site-packages
# You are using pip version 9.0.0, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from joblib import Parallel, delayed
import multiprocessing
    
# what are your inputs, and what operation do you want to 
# perform on each input. For example...


num_cores = multiprocessing.cpu_count()
    
#results = Parallel(n_jobs=num_cores)(delayed(processInput)(i) for i in inputs)

# %%
import time
import math
from numpy import array

total_error = []
lat_Long_Dict = {}
count = 0
start = time.time()
output_arr = []
def create_Lat_Long_Dict(row):
    columns1 = ['month1', 'year1']
    columns2 = ['month2', 'year2']
    
    #x_predict = np.append(np.array([row["month1"],row["year1"]]), np.array([row["month2"],row["year2"]]))

    df1 = pd.DataFrame(row[columns1])
    df1 = df1.transpose()
    df2 = pd.DataFrame(row[columns2])
    df2 = df2.transpose()
    df2.columns = columns1
    x_predict = df1.append(df2)
    intermediate_output = []
    m =  df_event[(row["se_lat"] < df_event["latitude"]) & (row["nw_lat"] > df_event["latitude"]) & (row["se_lon"] > df_event["longitude"]) & (row["nw_lon"] < df_event["longitude"])]
    if(len(m) > 0):
        data = []
        data.append(m[m["event_type"] == "accidentsAndIncidents"])
        data.append(m[m["event_type"] == "roadwork"])
        data.append(m[m["event_type"] == "precipitation"])
        data.append(m[m["event_type"] == "deviceStatus"])
        data.append(m[m["event_type"] == "obstruction"])
        data.append(m[m["event_type"] == "trafficConditions"])
        
        for i in range(0,6,1):
            cur_data = data[i]
            cur_data = cur_data.groupby(["year","month"])["count"].count().reset_index()
            columns = ['month', 'year']
            if (len(cur_data) != 0):
                data_test = cur_data[cur_data['year'] == 2014]
                data_train = cur_data[cur_data['year'] != 2014]
                x_train, y_train, x_test, y_test = data_train[columns] ,data_train['count'], data_test[columns], data_test['count']
                y = linear_regression(x_train, y_train, x_test, y_test, x_predict)
                intermediate_output.append(np.mean(y,axis=0))
            else:
                intermediate_output.append(0);
            
    output_arr.append(intermediate_output)   
    global count
    global start
    count = count + 1
    if count%100 == 0:
        end = time.time()
        print (str(count) + '\t' + str(end - start))
        start = time.time()

test = df_prediction_trial.head(100000).apply(lambda row:create_Lat_Long_Dict(row), axis= 1)
output_arr_final = array(output_arr) 
df_final_output = pd.DataFrame(output_arr_final)
df_final_output.to_csv("First2HundreadThousand.tsv",sep="\t")
print(math.sqrt(np.mean(total_error,axis=0)))
# Out:
# 100	5.441205978393555
# 7.577219727442768

# %%
row = df_prediction_trial.iloc[0]
columns1 = ['month1', 'year1']
columns2 = ['month2', 'year2']

df1 = pd.DataFrame(row[columns1])
df1 = df1.transpose()
df2 = pd.DataFrame(row[columns2])
df2 = df2.transpose()
df2.columns = columns1
df1 = df1.append(df2)
df1

# %%
import math
math.sqrt(2)

# %%
np.array([df_new["month"],df_new["year"]])

# %%
#df_prediction_trial.groupby().count()

cut_data = pd.cut(df["latitude"], 50000)
counts = pd.value_counts(cut_data)

print(counts)

# %%
len(df_prediction_trial)

# %%
lat_Long_Dict

# %%
df[df["year"] == 2014]
# Out:
#              closed_tstamp             event_type   latitude  longitude  \
