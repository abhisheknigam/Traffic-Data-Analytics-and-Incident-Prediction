# %%
import pylab
import pandas as pd

# %%
# !cat *.csv > merged.csv

# %%
df = pd.read_csv("merged.csv", na_values=['-'], delimiter=",", error_bad_lines=False)
# Out:
# b'Skipping line 5: expected 35 fields, saw 38\nSkipping line 7: expected 35 fields, saw 38\nSkipping line 15: expected 35 fields, saw 38\nSkipping line 16: expected 35 fields, saw 38\nSkipping line 17: expected 35 fields, saw 38\nSkipping line 19: expected 35 fields, saw 38\nSkipping line 52: expected 35 fields, saw 38\nSkipping line 53: expected 35 fields, saw 38\nSkipping line 58: expected 35 fields, saw 38\nSkipping line 59: expected 35 fields, saw 38\nSkipping line 63: expected 35 fields, saw 38\nSkipping line 66: expected 35 fields, saw 38\nSkipping line 87: expected 35 fields, saw 38\nSkipping line 88: expected 35 fields, saw 38\nSkipping line 89: expected 35 fields, saw 38\nSkipping line 90: expected 35 fields, saw 38\nSkipping line 767: expected 35 fields, saw 38\nSkipping line 773: expected 35 fields, saw 38\nSkipping line 774: expected 35 fields, saw 38\nSkipping line 782: expected 35 fields, saw 38\nSkipping line 815: expected 35 fields, saw 38\nSkipping line 817: expected
# ...

# %%
df = df[(pd.isnull(df["BEGIN_LAT"]) == False) & (df["BEGIN_LAT"].str.strip() != '')]

# %%
df[df["BEGIN_LAT"] != df["END_LAT"]]
# Out:
#      EVENT_ID               CZ_NAME_STR        BEGIN_LOCATION  BEGIN_DATE  \
# 21    5425471               FAIRFAX CO.           CENTREVILLE  09/17/2004
# 40    5463786               FAIRFAX CO.           GREAT FALLS  07/15/2005
# 53    5515175               FAIRFAX CO.             FRANCONIA  06/19/2006
# 90      18683               FAIRFAX CO.                 BURKE  03/16/2007
# 98      27283               FAIRFAX CO.               MC LEAN  05/27/2007
# 127     93438               FAIRFAX CO.               TREMONT  04/20/2008
# 128     93777               FAIRFAX CO.             MT VERNON  04/21/2008
# 130     98696               FAIRFAX CO.             MT VERNON  05/09/2008
# 139    104345               FAIRFAX CO.          SUNSET HILLS  06/04/2008
# 143    104344               FAIRFAX CO.                OAKTON  06/04/2008
# 151    104173               FAIRFAX CO.  CHESTERBROOK GARDENS  06/04/2008
# 155    104658               FAIRFAX CO.             WAYNEWOOD  06/04/2008
# ...

# %%
df
# Out:
#      EVENT_ID               CZ_NAME_STR    BEGIN_LOCATION  BEGIN_DATE  \
# 2     5335543               FAIRFAX CO.         MT VERNON  10/14/2003
# 4     5380250               FAIRFAX CO.           MC LEAN  11/19/2003
# 13    5395450               FAIRFAX CO.       GREAT FALLS  05/02/2004
# 14    5395456               FAIRFAX CO.           MC LEAN  05/05/2004
# 15    5395457               FAIRFAX CO.           MC LEAN  05/05/2004
# 16    5406297               FAIRFAX CO.       GREAT FALLS  06/01/2004
# 18    5421723               FAIRFAX CO.         CHANTILLY  08/11/2004
# 19    5421720               FAIRFAX CO.         ANNANDALE  08/11/2004
# 20    5421718               FAIRFAX CO.         ANNANDALE  08/11/2004
# 21    5425471               FAIRFAX CO.       CENTREVILLE  09/17/2004
# 24    5436657               FAIRFAX CO.         ANNANDALE  01/14/2005
# 28    5440154               FAIRFAX CO.           HERNDON  03/28/2005
# ...

# %%
df_Storm = pd.read_csv("stormdata_2013.csv", na_values=['-'], delimiter=",", error_bad_lines=False)

# %%
df_state = df_Storm[(df_Storm["STATE"] == "DISTRICT OF COLUMBIA")|(df_Storm["STATE"] == "MARYLAND")|(df_Storm["STATE"] == "VIRGINIA")]

# %%
df_state = df_state[(pd.isnull(df_state["BEGIN_LAT"]) == False)]

# %%
df.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'LAST_MOD_DATE',
#        'LAST_MOD_TIME', 'LAST_CERT_DATE', 'LAST_CERT_TIME', 'LAST_MOD',
#        'LAST_CERT', 'ADDCORR_FLG', 'ADDCORR_DATE'],
# ...

# %%
df['EVENT_TYPE'].unique()
# Out:
# array(['Drought', 'Sneakerwave', 'Heavy Snow', 'Flood', 'Dense Fog',
#        'High Surf', 'Frost/Freeze', 'High Wind', 'Marine High Wind',
#        'Winter Weather', 'Extreme Cold/Wind Chill', 'Cold/Wind Chill',
#        'Funnel Cloud', 'Heavy Rain', 'Flash Flood',
#        'Marine Thunderstorm Wind', 'Debris Flow', 'Waterspout',
#        'Strong Wind', 'Blizzard', 'Winter Storm', 'Thunderstorm Wind',
#        'Ice Storm', 'Tornado', 'Coastal Flood', 'Dust Storm', 'Hail',
#        'Lake-Effect Snow', 'Avalanche', 'Astronomical Low Tide', 'Sleet',
#        'Marine Strong Wind', 'Tropical Storm', 'Lightning', 'Wildfire',
#        'Rip Current', 'Marine Hail', 'Dust Devil', 'Excessive Heat',
#        'Storm Surge/Tide', 'Marine Dense Fog', 'Heat', 'Tsunami',
#        'Dense Smoke', 'Hurricane', 'Freezing Fog'], dtype=object)

# %%
cols = ['BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON']
df[cols]
# Out:
#        BEGIN_LAT  BEGIN_LON  END_LAT  END_LON
# 0            NaN        NaN      NaN      NaN
# 1            NaN        NaN      NaN      NaN
# 2            NaN        NaN      NaN      NaN
# 3            NaN        NaN      NaN      NaN
# 4            NaN        NaN      NaN      NaN
# 5            NaN        NaN      NaN      NaN
# 6            NaN        NaN      NaN      NaN
# 7            NaN        NaN      NaN      NaN
# 8            NaN        NaN      NaN      NaN
# 9            NaN        NaN      NaN      NaN
# 10           NaN        NaN      NaN      NaN
# 11           NaN        NaN      NaN      NaN
# 12           NaN        NaN      NaN      NaN
# 13           NaN        NaN      NaN      NaN
# 14           NaN        NaN      NaN      NaN
# 15           NaN        NaN      NaN      NaN
# 16           NaN        NaN      NaN      NaN
# 17           NaN        NaN      NaN      NaN
# 18           NaN        NaN      NaN      NaN
# ...
